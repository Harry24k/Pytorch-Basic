# %% [markdown]
# # 20. LSTM with Moby Dick

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

from sklearn.feature_extraction.text import CountVectorizer

import random
import numpy as np

# %% [markdown]
# ## 20.1 Preparing Data

# %%
nltk.download("gutenberg")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\slcf\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\slcf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
raw = nltk.corpus.gutenberg.raw("melville-moby_dick.txt")
print(raw[21945:23000])
raw = raw[21945:200000]
# Out:
# CHAPTER 1
#
# Loomings.
#
#
# Call me Ishmael.  Some years ago--never mind how long
# precisely--having little or no money in my purse, and nothing
# particular to interest me on shore, I thought I would sail about a
# little and see the watery part of the world.  It is a way I have of
# driving off the spleen and regulating the circulation.  Whenever I
# find myself growing grim about the mouth; whenever it is a damp,
# drizzly November in my soul; whenever I find myself involuntarily
# pausing before coffin warehouses, and bringing up the rear of every
# funeral I meet; and especially whenever my hypos get such an upper
# hand of me, that it requires a strong moral principle to prevent me
# from deliberately stepping into the street, and methodically knocking
# people's hats off--then, I account it high time to get to sea as soon
# as I can.  This is my substitute for pistol and ball.  With a
# philosophical flourish Cato throws himself upon his sword; I quietly
# take to the ship.  There is nothing surprising in this.  If they but
# knew it, almost all

# %% [markdown]
# ## 20.2 BoW

# %%
tokens = word_tokenize(raw)
print(tokens[:50])
# Out:
# ['CHAPTER', '1', 'Loomings', '.', 'Call', 'me', 'Ishmael', '.', 'Some', 'years', 'ago', '--', 'never', 'mind', 'how', 'long', 'precisely', '--', 'having', 'little', 'or', 'no', 'money', 'in', 'my', 'purse', ',', 'and', 'nothing', 'particular', 'to', 'interest', 'me', 'on', 'shore', ',', 'I', 'thought', 'I', 'would', 'sail', 'about', 'a', 'little', 'and', 'see', 'the', 'watery', 'part', 'of']

# %%
def tokenizer(doc):
    return ["/".join(p) for p in pos_tag(doc)]

tokens = tokenizer(tokens)

print(tokens[:50])
# Out:
# ['CHAPTER/NN', '1/CD', 'Loomings/NNP', './.', 'Call/VB', 'me/PRP', 'Ishmael/NNP', './.', 'Some/DT', 'years/NNS', 'ago/RB', '--/:', 'never/RB', 'mind/VB', 'how/WRB', 'long/JJ', 'precisely/RB', '--/:', 'having/VBG', 'little/JJ', 'or/CC', 'no/DT', 'money/NN', 'in/IN', 'my/PRP$', 'purse/NN', ',/,', 'and/CC', 'nothing/NN', 'particular/JJ', 'to/TO', 'interest/NN', 'me/PRP', 'on/IN', 'shore/NN', ',/,', 'I/PRP', 'thought/VBD', 'I/PRP', 'would/MD', 'sail/VB', 'about/IN', 'a/DT', 'little/JJ', 'and/CC', 'see/VB', 'the/DT', 'watery/JJ', 'part/NN', 'of/IN']

# %%
cnv = CountVectorizer(analyzer = 'word',
                             tokenizer=lambda x: x.split(', '),
                             preprocessor = None, 
                             stop_words = None,
                             ngram_range=(1, 1),
                             lowercase=False
                            )

data = cnv.fit_transform(tokens).toarray()

# %%
len(data)
# Out:
# 36924

# %%
cnv.inverse_transform(data)
# Out:
# [array(['CHAPTER/NN'], dtype='<U26'),
#  array(['1/CD'], dtype='<U26'),
#  array(['Loomings/NNP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Call/VB'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array(['Ishmael/NNP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Some/DT'], dtype='<U26'),
#  array(['years/NNS'], dtype='<U26'),
#  array(['ago/RB'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['never/RB'], dtype='<U26'),
#  array(['mind/VB'], dtype='<U26'),
#  array(['how/WRB'], dtype='<U26'),
#  array(['long/JJ'], dtype='<U26'),
#  array(['precisely/RB'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['having/VBG'], dtype='<U26'),
#  array(['little/JJ'], dtype='<U26'),
#  array(['or/CC'], dtype='<U26'),
#  array(['no/DT'], dtype='<U26'),
#  array(['money/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['my/PRP$'], dtype='<U26'),
#  array(['purse/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['nothing/NN'], dtype='<U26'),
#  array(['particular/JJ'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['interest/NN'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array(['on/IN'], dtype='<U26'),
#  array(['shore/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['thought/VBD'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['would/MD'], dtype='<U26'),
#  array(['sail/VB'], dtype='<U26'),
#  array(['about/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['little/JJ'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['see/VB'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['watery/JJ'], dtype='<U26'),
#  array(['part/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['world/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['It/PRP'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['way/NN'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['have/VBP'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['driving/VBG'], dtype='<U26'),
#  array(['off/RP'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['spleen/NN'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['regulating/VBG'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['circulation/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Whenever/WRB'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['find/VBP'], dtype='<U26'),
#  array(['myself/PRP'], dtype='<U26'),
#  array(['growing/VBG'], dtype='<U26'),
#  array(['grim/JJ'], dtype='<U26'),
#  array(['about/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['mouth/NN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['whenever/WRB'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['damp/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['drizzly/JJ'], dtype='<U26'),
#  array(['November/NNP'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['my/PRP$'], dtype='<U26'),
#  array(['soul/NN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['whenever/WRB'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['find/VBP'], dtype='<U26'),
#  array(['myself/PRP'], dtype='<U26'),
#  array(['involuntarily/RB'], dtype='<U26'),
#  array(['pausing/VBG'], dtype='<U26'),
#  array(['before/IN'], dtype='<U26'),
#  array(['coffin/NN'], dtype='<U26'),
#  array(['warehouses/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['bringing/VBG'], dtype='<U26'),
#  array(['up/RP'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['rear/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['every/DT'], dtype='<U26'),
#  array(['funeral/JJ'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['meet/VBP'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['especially/RB'], dtype='<U26'),
#  array(['whenever/WRB'], dtype='<U26'),
#  array(['my/PRP$'], dtype='<U26'),
#  array(['hypos/NN'], dtype='<U26'),
#  array(['get/VB'], dtype='<U26'),
#  array(['such/JJ'], dtype='<U26'),
#  array(['an/DT'], dtype='<U26'),
#  array(['upper/JJ'], dtype='<U26'),
#  array(['hand/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['that/IN'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['requires/VBZ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['strong/JJ'], dtype='<U26'),
#  array(['moral/JJ'], dtype='<U26'),
#  array(['principle/NN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['prevent/VB'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['deliberately/RB'], dtype='<U26'),
#  array(['stepping/VBG'], dtype='<U26'),
#  array(['into/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['street/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['methodically/RB'], dtype='<U26'),
#  array(['knocking/VBG'], dtype='<U26'),
#  array(['people/NNS'], dtype='<U26'),
#  array(["'s/POS"], dtype='<U26'),
#  array(['hats/NNS'], dtype='<U26'),
#  array(['off/VBP'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['then/RB'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['account/VBP'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['high/JJ'], dtype='<U26'),
#  array(['time/NN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['get/VB'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['sea/VB'], dtype='<U26'),
#  array(['as/RB'], dtype='<U26'),
#  array(['soon/RB'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['can/MD'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['This/DT'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['my/PRP$'], dtype='<U26'),
#  array(['substitute/NN'], dtype='<U26'),
#  array(['for/IN'], dtype='<U26'),
#  array(['pistol/NN'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['ball/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['With/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['philosophical/JJ'], dtype='<U26'),
#  array(['flourish/JJ'], dtype='<U26'),
#  array(['Cato/NNP'], dtype='<U26'),
#  array(['throws/VBZ'], dtype='<U26'),
#  array(['himself/PRP'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['sword/NN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['I/PRP'], dtype='<U26'),
#  array(['quietly/RB'], dtype='<U26'),
#  array(['take/VBP'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['ship/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['There/EX'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['nothing/NN'], dtype='<U26'),
#  array(['surprising/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['this/DT'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['If/IN'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['but/CC'], dtype='<U26'),
#  array(['knew/VBD'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['almost/RB'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['men/NNS'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['their/PRP$'], dtype='<U26'),
#  array(['degree/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['time/NN'], dtype='<U26'),
#  array(['or/CC'], dtype='<U26'),
#  array(['other/JJ'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['cherish/JJ'], dtype='<U26'),
#  array(['very/RB'], dtype='<U26'),
#  array(['nearly/RB'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['same/JJ'], dtype='<U26'),
#  array(['feelings/NNS'], dtype='<U26'),
#  array(['towards/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['ocean/NN'], dtype='<U26'),
#  array(['with/IN'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['There/EX'], dtype='<U26'),
#  array(['now/RB'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['your/PRP$'], dtype='<U26'),
#  array(['insular/JJ'], dtype='<U26'),
#  array(['city/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['Manhattoes/NNP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['belted/VBN'], dtype='<U26'),
#  array(['round/NN'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['wharves/NNS'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['Indian/JJ'], dtype='<U26'),
#  array(['isles/NNS'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['coral/JJ'], dtype='<U26'),
#  array(['reefs/NNS'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['commerce/NN'], dtype='<U26'),
#  array(['surrounds/VBZ'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['with/IN'], dtype='<U26'),
#  array(['her/PRP$'], dtype='<U26'),
#  array(['surf/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Right/NNP'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['left/VBD'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['streets/NNS'], dtype='<U26'),
#  array(['take/VBP'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['waterward/RB'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Its/PRP$'], dtype='<U26'),
#  array(['extreme/JJ'], dtype='<U26'),
#  array(['downtown/NN'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['battery/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['where/WRB'], dtype='<U26'),
#  array(['that/DT'], dtype='<U26'),
#  array(['noble/JJ'], dtype='<U26'),
#  array(['mole/NN'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['washed/VBN'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['waves/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['cooled/VBN'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['breezes/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['which/WDT'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['few/JJ'], dtype='<U26'),
#  array(['hours/NNS'], dtype='<U26'),
#  array(['previous/JJ'], dtype='<U26'),
#  array(['were/VBD'], dtype='<U26'),
#  array(['out/IN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['sight/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['land/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Look/VB'], dtype='<U26'),
#  array(['at/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['crowds/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['water-gazers/NNS'], dtype='<U26'),
#  array(['there/RB'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Circumambulate/VB'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['city/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['dreamy/JJ'], dtype='<U26'),
#  array(['Sabbath/NNP'], dtype='<U26'),
#  array(['afternoon/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Go/VB'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['Corlears/NNP'], dtype='<U26'),
#  array(['Hook/NNP'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['Coenties/NNP'], dtype='<U26'),
#  array(['Slip/NNP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['thence/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['Whitehall/NNP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['northward/RB'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['What/WP'], dtype='<U26'),
#  array(['do/VBP'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['see/VB'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['Posted/VBD'], dtype='<U26'),
#  array(['like/JJ'], dtype='<U26'),
#  array(['silent/JJ'], dtype='<U26'),
#  array(['sentinels/NNS'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['around/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['town/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['stand/VB'], dtype='<U26'),
#  array(['thousands/NNS'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['thousands/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['mortal/JJ'], dtype='<U26'),
#  array(['men/NNS'], dtype='<U26'),
#  array(['fixed/VBN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['ocean/JJ'], dtype='<U26'),
#  array(['reveries/NNS'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Some/DT'], dtype='<U26'),
#  array(['leaning/VBG'], dtype='<U26'),
#  array(['against/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['spiles/NNS'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['seated/VBN'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['pier-heads/NNS'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['looking/VBG'], dtype='<U26'),
#  array(['over/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['bulwarks/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['ships/NNS'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['China/NNP'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['high/JJ'], dtype='<U26'),
#  array(['aloft/RB'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['rigging/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['if/IN'], dtype='<U26'),
#  array(['striving/VBG'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['get/VB'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['still/RB'], dtype='<U26'),
#  array(['better/RBR'], dtype='<U26'),
#  array(['seaward/JJ'], dtype='<U26'),
#  array(['peep/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['But/CC'], dtype='<U26'),
#  array(['these/DT'], dtype='<U26'),
#  array(['are/VBP'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['landsmen/NNS'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['week/NN'], dtype='<U26'),
#  array(['days/NNS'], dtype='<U26'),
#  array(['pent/VBP'], dtype='<U26'),
#  array(['up/RP'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['lath/NN'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['plaster/NN'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['tied/VBN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['counters/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['nailed/VBD'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['benches/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['clinched/VBD'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['desks/NNS'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['How/WRB'], dtype='<U26'),
#  array(['then/RB'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['this/DT'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['Are/VBP'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['green/JJ'], dtype='<U26'),
#  array(['fields/NNS'], dtype='<U26'),
#  array(['gone/VBN'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['What/WP'], dtype='<U26'),
#  array(['do/VBP'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['here/RB'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['But/CC'], dtype='<U26'),
#  array(['look/NN'], dtype='<U26'),
#  array(['!/.'], dtype='<U26'),
#  array(['here/RB'], dtype='<U26'),
#  array(['come/VBN'], dtype='<U26'),
#  array(['more/JJR'], dtype='<U26'),
#  array(['crowds/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['pacing/VBG'], dtype='<U26'),
#  array(['straight/NN'], dtype='<U26'),
#  array(['for/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['seemingly/RB'], dtype='<U26'),
#  array(['bound/VBN'], dtype='<U26'),
#  array(['for/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['dive/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Strange/JJ'], dtype='<U26'),
#  array(['!/.'], dtype='<U26'),
#  array(['Nothing/NN'], dtype='<U26'),
#  array(['will/MD'], dtype='<U26'),
#  array(['content/VB'], dtype='<U26'),
#  array(['them/PRP'], dtype='<U26'),
#  array(['but/CC'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['extremest/JJS'], dtype='<U26'),
#  array(['limit/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['land/NN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['loitering/VBG'], dtype='<U26'),
#  array(['under/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['shady/JJ'], dtype='<U26'),
#  array(['lee/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['yonder/NN'], dtype='<U26'),
#  array(['warehouses/NNS'], dtype='<U26'),
#  array(['will/MD'], dtype='<U26'),
#  array(['not/RB'], dtype='<U26'),
#  array(['suffice/VB'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['No/DT'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['They/PRP'], dtype='<U26'),
#  array(['must/MD'], dtype='<U26'),
#  array(['get/VB'], dtype='<U26'),
#  array(['just/RB'], dtype='<U26'),
#  array(['as/RB'], dtype='<U26'),
#  array(['nigh/JJ'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['possibly/RB'], dtype='<U26'),
#  array(['can/MD'], dtype='<U26'),
#  array(['without/IN'], dtype='<U26'),
#  array(['falling/VBG'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['And/CC'], dtype='<U26'),
#  array(['there/EX'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['stand/VBP'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['miles/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['them/PRP'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['leagues/NNS'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Inlanders/NNS'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['come/VBP'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['lanes/NNS'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['alleys/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['streets/NNS'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['avenues/NNS'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['north/RB'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['east/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['south/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['west/JJS'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Yet/CC'], dtype='<U26'),
#  array(['here/RB'], dtype='<U26'),
#  array(['they/PRP'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['unite/JJ'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Tell/VB'], dtype='<U26'),
#  array(['me/PRP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['does/VBZ'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['magnetic/JJ'], dtype='<U26'),
#  array(['virtue/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['needles/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['compasses/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['all/PDT'], dtype='<U26'),
#  array(['those/DT'], dtype='<U26'),
#  array(['ships/NNS'], dtype='<U26'),
#  array(['attract/VBP'], dtype='<U26'),
#  array(['them/PRP'], dtype='<U26'),
#  array(['thither/RP'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['Once/RB'], dtype='<U26'),
#  array(['more/RBR'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Say/NNP'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['are/VBP'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['country/NN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['high/JJ'], dtype='<U26'),
#  array(['land/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['lakes/NNS'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Take/VB'], dtype='<U26'),
#  array(['almost/RB'], dtype='<U26'),
#  array(['any/DT'], dtype='<U26'),
#  array(['path/NN'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['please/VBP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['ten/VB'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['one/CD'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['carries/VBZ'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['down/RP'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['dale/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['leaves/VBZ'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['there/EX'], dtype='<U26'),
#  array(['by/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['pool/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['stream/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['There/EX'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['magic/JJ'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Let/VB'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['most/RBS'], dtype='<U26'),
#  array(['absent-minded/JJ'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['men/NNS'], dtype='<U26'),
#  array(['be/VB'], dtype='<U26'),
#  array(['plunged/VBN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['deepest/NN'], dtype='<U26'),
#  array(['reveries/NNS'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['stand/VBP'], dtype='<U26'),
#  array(['that/IN'], dtype='<U26'),
#  array(['man/NN'], dtype='<U26'),
#  array(['on/IN'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['legs/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['set/VBN'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['feet/NNS'], dtype='<U26'),
#  array(['a-going/JJ'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['he/PRP'], dtype='<U26'),
#  array(['will/MD'], dtype='<U26'),
#  array(['infallibly/RB'], dtype='<U26'),
#  array(['lead/VB'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['if/IN'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array(['there/RB'], dtype='<U26'),
#  array(['be/VB'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['that/DT'], dtype='<U26'),
#  array(['region/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Should/MD'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['ever/RB'], dtype='<U26'),
#  array(['be/VB'], dtype='<U26'),
#  array(['athirst/RB'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['great/JJ'], dtype='<U26'),
#  array(['American/JJ'], dtype='<U26'),
#  array(['desert/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['try/VB'], dtype='<U26'),
#  array(['this/DT'], dtype='<U26'),
#  array(['experiment/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['if/IN'], dtype='<U26'),
#  array(['your/PRP$'], dtype='<U26'),
#  array(['caravan/NN'], dtype='<U26'),
#  array(['happen/VB'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['be/VB'], dtype='<U26'),
#  array(['supplied/VBN'], dtype='<U26'),
#  array(['with/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['metaphysical/JJ'], dtype='<U26'),
#  array(['professor/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Yes/UH'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['every/DT'], dtype='<U26'),
#  array(['one/CD'], dtype='<U26'),
#  array(['knows/VBZ'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['meditation/NN'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array(['are/VBP'], dtype='<U26'),
#  array(['wedded/VBN'], dtype='<U26'),
#  array(['for/IN'], dtype='<U26'),
#  array(['ever/RB'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['But/CC'], dtype='<U26'),
#  array(['here/RB'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['an/DT'], dtype='<U26'),
#  array(['artist/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['He/PRP'], dtype='<U26'),
#  array(['desires/VBZ'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['paint/VB'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['dreamiest/JJS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['shadiest/JJS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['quietest/JJS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['most/RBS'], dtype='<U26'),
#  array(['enchanting/JJ'], dtype='<U26'),
#  array(['bit/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['romantic/JJ'], dtype='<U26'),
#  array(['landscape/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['all/PDT'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['valley/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['Saco/NNP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['What/WP'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['chief/JJ'], dtype='<U26'),
#  array(['element/NN'], dtype='<U26'),
#  array(['he/PRP'], dtype='<U26'),
#  array(['employs/VBZ'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['There/EX'], dtype='<U26'),
#  array(['stand/VB'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['trees/NNS'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['each/DT'], dtype='<U26'),
#  array(['with/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['hollow/JJ'], dtype='<U26'),
#  array(['trunk/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['if/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['hermit/NN'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['crucifix/NN'], dtype='<U26'),
#  array(['were/VBD'], dtype='<U26'),
#  array(['within/IN'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['here/RB'], dtype='<U26'),
#  array(['sleeps/VB'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['meadow/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['there/RB'], dtype='<U26'),
#  array(['sleep/VB'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['cattle/NNS'], dtype='<U26'),
#  array([';/:'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['up/RB'], dtype='<U26'),
#  array(['from/IN'], dtype='<U26'),
#  array(['yonder/JJR'], dtype='<U26'),
#  array(['cottage/NN'], dtype='<U26'),
#  array(['goes/VBZ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['sleepy/JJ'], dtype='<U26'),
#  array(['smoke/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Deep/NNP'], dtype='<U26'),
#  array(['into/IN'], dtype='<U26'),
#  array(['distant/JJ'], dtype='<U26'),
#  array(['woodlands/NNS'], dtype='<U26'),
#  array(['winds/VBZ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['mazy/JJ'], dtype='<U26'),
#  array(['way/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['reaching/VBG'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['overlapping/VBG'], dtype='<U26'),
#  array(['spurs/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['mountains/NNS'], dtype='<U26'),
#  array(['bathed/VBN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['their/PRP$'], dtype='<U26'),
#  array(['hill-side/JJ'], dtype='<U26'),
#  array(['blue/NN'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['But/CC'], dtype='<U26'),
#  array(['though/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['picture/NN'], dtype='<U26'),
#  array(['lies/VBZ'], dtype='<U26'),
#  array(['thus/RB'], dtype='<U26'),
#  array(['tranced/VBN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['and/CC'], dtype='<U26'),
#  array(['though/IN'], dtype='<U26'),
#  array(['this/DT'], dtype='<U26'),
#  array(['pine-tree/JJ'], dtype='<U26'),
#  array(['shakes/NNS'], dtype='<U26'),
#  array(['down/RP'], dtype='<U26'),
#  array(['its/PRP$'], dtype='<U26'),
#  array(['sighs/NNS'], dtype='<U26'),
#  array(['like/IN'], dtype='<U26'),
#  array(['leaves/NNS'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['this/DT'], dtype='<U26'),
#  array(['shepherd/NN'], dtype='<U26'),
#  array(["'s/POS"], dtype='<U26'),
#  array(['head/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['yet/RB'], dtype='<U26'),
#  array(['all/DT'], dtype='<U26'),
#  array(['were/VBD'], dtype='<U26'),
#  array(['vain/VBN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['unless/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['shepherd/NN'], dtype='<U26'),
#  array(["'s/POS"], dtype='<U26'),
#  array(['eye/NN'], dtype='<U26'),
#  array(['were/VBD'], dtype='<U26'),
#  array(['fixed/VBN'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['magic/JJ'], dtype='<U26'),
#  array(['stream/NN'], dtype='<U26'),
#  array(['before/IN'], dtype='<U26'),
#  array(['him/PRP'], dtype='<U26'),
#  array(['./.'], dtype='<U26'),
#  array(['Go/VB'], dtype='<U26'),
#  array(['visit/IN'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['Prairies/NNPS'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['June/NNP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['when/WRB'], dtype='<U26'),
#  array(['for/IN'], dtype='<U26'),
#  array(['scores/NNS'], dtype='<U26'),
#  array(['on/IN'], dtype='<U26'),
#  array(['scores/NNS'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['miles/NNS'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['wade/VBP'], dtype='<U26'),
#  array(['knee-deep/JJ'], dtype='<U26'),
#  array(['among/IN'], dtype='<U26'),
#  array(['Tiger-lilies/NNPS'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['what/WP'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['one/CD'], dtype='<U26'),
#  array(['charm/NN'], dtype='<U26'),
#  array(['wanting/NN'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['Water/NNP'], dtype='<U26'),
#  array(['--/:'], dtype='<U26'),
#  array(['there/EX'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['not/RB'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['drop/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['water/NN'], dtype='<U26'),
#  array(['there/EX'], dtype='<U26'),
#  array(['!/.'], dtype='<U26'),
#  array(['Were/NNP'], dtype='<U26'),
#  array(['Niagara/NNP'], dtype='<U26'),
#  array(['but/CC'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['cataract/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['sand/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['would/MD'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['travel/VB'], dtype='<U26'),
#  array(['your/PRP$'], dtype='<U26'),
#  array(['thousand/NN'], dtype='<U26'),
#  array(['miles/NNS'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['see/VB'], dtype='<U26'),
#  array(['it/PRP'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['Why/WRB'], dtype='<U26'),
#  array(['did/VBD'], dtype='<U26'),
#  array(['the/DT'], dtype='<U26'),
#  array(['poor/JJ'], dtype='<U26'),
#  array(['poet/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['Tennessee/NNP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['suddenly/RB'], dtype='<U26'),
#  array(['receiving/VBG'], dtype='<U26'),
#  array(['two/CD'], dtype='<U26'),
#  array(['handfuls/NN'], dtype='<U26'),
#  array(['of/IN'], dtype='<U26'),
#  array(['silver/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['deliberate/VB'], dtype='<U26'),
#  array(['whether/IN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['buy/VB'], dtype='<U26'),
#  array(['him/PRP'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['coat/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['which/WDT'], dtype='<U26'),
#  array(['he/PRP'], dtype='<U26'),
#  array(['sadly/RB'], dtype='<U26'),
#  array(['needed/VBD'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['or/CC'], dtype='<U26'),
#  array(['invest/VB'], dtype='<U26'),
#  array(['his/PRP$'], dtype='<U26'),
#  array(['money/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['pedestrian/JJ'], dtype='<U26'),
#  array(['trip/NN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['Rockaway/NNP'], dtype='<U26'),
#  array(['Beach/NNP'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['Why/WRB'], dtype='<U26'),
#  array(['is/VBZ'], dtype='<U26'),
#  array(['almost/RB'], dtype='<U26'),
#  array(['every/DT'], dtype='<U26'),
#  array(['robust/JJ'], dtype='<U26'),
#  array(['healthy/JJ'], dtype='<U26'),
#  array(['boy/NN'], dtype='<U26'),
#  array(['with/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['robust/JJ'], dtype='<U26'),
#  array(['healthy/JJ'], dtype='<U26'),
#  array(['soul/NN'], dtype='<U26'),
#  array(['in/IN'], dtype='<U26'),
#  array(['him/PRP'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['at/IN'], dtype='<U26'),
#  array(['some/DT'], dtype='<U26'),
#  array(['time/NN'], dtype='<U26'),
#  array(['or/CC'], dtype='<U26'),
#  array(['other/JJ'], dtype='<U26'),
#  array(['crazy/NN'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['go/VB'], dtype='<U26'),
#  array(['to/TO'], dtype='<U26'),
#  array(['sea/VB'], dtype='<U26'),
#  array(['?/.'], dtype='<U26'),
#  array(['Why/WRB'], dtype='<U26'),
#  array(['upon/IN'], dtype='<U26'),
#  array(['your/PRP$'], dtype='<U26'),
#  array(['first/JJ'], dtype='<U26'),
#  array(['voyage/NN'], dtype='<U26'),
#  array(['as/IN'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['passenger/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  array(['did/VBD'], dtype='<U26'),
#  array(['you/PRP'], dtype='<U26'),
#  array(['yourself/PRP'], dtype='<U26'),
#  array(['feel/VB'], dtype='<U26'),
#  array(['such/JJ'], dtype='<U26'),
#  array(['a/DT'], dtype='<U26'),
#  array(['mystical/JJ'], dtype='<U26'),
#  array(['vibration/NN'], dtype='<U26'),
#  array([',/,'], dtype='<U26'),
#  ...]

# %% [markdown]
# ## 20.3 Define Model

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size,hidden_size,num_layers, dropout = 0.5)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, hidden, cell):
        out, (hidden, cell) = self.lstm(input.view(1,1,-1),(hidden,cell))
        out = self.fc(out.view(1,-1))
        return out,hidden, cell

    def init_hidden_cell(self):
        hidden = Variable(torch.zeros(self.num_layers, 1, self.hidden_size)).cuda()
        cell = Variable(torch.zeros(self.num_layers, 1, self.hidden_size)).cuda()
        return hidden, cell

# %%
model = LSTM(len(data[0]), 1000, len(data[0]), 2).cuda()

# %% [markdown]
# ## 20.4 Model Training

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss = nn.CrossEntropyLoss()

# %%
step = 10
num_epochs = 10

# %%
for epoch in range(num_epochs):
    
    sp = list(range(0, len(data) - 2 * step, step))
    sp = np.add(sp, random.randint(0, step))
    random.shuffle(sp)
    
    for i in range(len(sp)) :
    
        (hidden, cell) = model.init_hidden_cell()

        cost = 0

        for pos in range(sp[i], sp[i] + step):
            X = Variable(torch.from_numpy(data[pos]).type(torch.FloatTensor)).cuda()
            y = torch.from_numpy(data[pos+1]).cuda()
            _, y = y.max(dim=0)

            pre, hidden, cell = model(X,hidden,cell)
            cost += loss(pre,Variable(y).cuda())

        cost.backward()
        optimizer.step()

        if (i + 1) % 100 == 0 :
            print('Epoch [%d/%d], Iter [%d/%d] Loss: %.4f'
                     %(epoch+1, num_epochs, i + 1, len(sp), cost.data[0]))
# Out:
# Epoch [1/10], Iter [100/3691] Loss: 63.3960
# Epoch [1/10], Iter [200/3691] Loss: 100.2390
# Epoch [1/10], Iter [300/3691] Loss: 83.4005
# Epoch [1/10], Iter [400/3691] Loss: 119.0685
# Epoch [1/10], Iter [500/3691] Loss: 140.6733
# Epoch [1/10], Iter [600/3691] Loss: 111.3818
# Epoch [1/10], Iter [700/3691] Loss: 118.6159
# Epoch [1/10], Iter [800/3691] Loss: 129.9223
# Epoch [1/10], Iter [900/3691] Loss: 173.4347
# Epoch [1/10], Iter [1000/3691] Loss: 178.0553
# Epoch [1/10], Iter [1100/3691] Loss: 250.2615
# Epoch [1/10], Iter [1200/3691] Loss: 165.1613
# Epoch [1/10], Iter [1300/3691] Loss: 239.2156
# Epoch [1/10], Iter [1400/3691] Loss: 197.4339
# Epoch [1/10], Iter [1500/3691] Loss: 225.6682
# Epoch [1/10], Iter [1600/3691] Loss: 186.3174
# Epoch [1/10], Iter [1700/3691] Loss: 265.4194
# Epoch [1/10], Iter [1800/3691] Loss: 261.4159
# Epoch [1/10], Iter [1900/3691] Loss: 285.1147
# Epoch [1/10], Iter [2000/3691] Loss: 280.6012
# Epoch [1/10], Iter [2100/3691] Loss: 270.9442
# Epoch [1/10], Iter [2200/3691] Loss: 283.5450
# Epoch [1/10], Iter [2300/3691] Loss: 269.8598
# Epoch [1/10], Iter [2400/3691] Loss: 371.0522
# Epoch [1/10], Iter [2500/3691] Loss: 331.5424
# Epoch [1/10], Iter [2600/3691] Loss: 280.2632
# Epoch [1/10], Iter [2700/3691] Loss: 329.5479
# Epoch [1/10], Iter [2800/3691] Loss: 320.0225
# Epoch [1/10], Iter [2900/3691] Loss: 376.2870
# Epoch [1/10], Iter [3000/3691] Loss: 417.1445
# Epoch [1/10], Iter [3100/3691] Loss: 255.6414
# Epoch [2/10], Iter [1500/3691] Loss: 561.7452
# Epoch [2/10], Iter [1600/3691] Loss: 505.0750
# Epoch [2/10], Iter [1700/3691] Loss: 459.7460
# Epoch [2/10], Iter [1800/3691] Loss: 462.6353
# Epoch [2/10], Iter [1900/3691] Loss: 329.4658
# Epoch [2/10], Iter [2000/3691] Loss: 559.7594
# Epoch [2/10], Iter [2100/3691] Loss: 231.5830
# Epoch [2/10], Iter [2200/3691] Loss: 375.6927
# Epoch [2/10], Iter [2300/3691] Loss: 548.4491
# Epoch [2/10], Iter [2400/3691] Loss: 830.6744
# Epoch [10/10], Iter [700/3691] Loss: 1001.6599
# Epoch [10/10], Iter [800/3691] Loss: 443.1823
# Epoch [10/10], Iter [900/3691] Loss: 243.1091
# Epoch [10/10], Iter [1000/3691] Loss: 703.2206
# Epoch [10/10], Iter [1100/3691] Loss: 563.3644
# Epoch [10/10], Iter [1200/3691] Loss: 930.7334
# Epoch [10/10], Iter [1300/3691] Loss: 533.5648
# Epoch [10/10], Iter [1400/3691] Loss: 365.8405
# Epoch [10/10], Iter [1500/3691] Loss: 778.3419
# Epoch [10/10], Iter [1600/3691] Loss: 440.3697
# Epoch [10/10], Iter [1700/3691] Loss: 1168.6951
# Epoch [10/10], Iter [1800/3691] Loss: 983.3330
# Epoch [10/10], Iter [1900/3691] Loss: 828.9751
# Epoch [10/10], Iter [2000/3691] Loss: 880.1494
# Epoch [10/10], Iter [2100/3691] Loss: 367.5635
# Epoch [10/10], Iter [2200/3691] Loss: 923.7296
# Epoch [10/10], Iter [2300/3691] Loss: 850.0359
# Epoch [10/10], Iter [2400/3691] Loss: 810.6140
# Epoch [10/10], Iter [2500/3691] Loss: 845.3115
# Epoch [10/10], Iter [2600/3691] Loss: 920.9352
# Epoch [10/10], Iter [2700/3691] Loss: 759.8461
# Epoch [10/10], Iter [2800/3691] Loss: 711.9467
# Epoch [10/10], Iter [2900/3691] Loss: 768.4352
# Epoch [10/10], Iter [3000/3691] Loss: 1071.4612
# Epoch [10/10], Iter [3100/3691] Loss: 625.3170
# Epoch [10/10], Iter [3200/3691] Loss: 542.2490
# Epoch [10/10], Iter [3300/3691] Loss: 861.1431
# Epoch [10/10], Iter [3400/3691] Loss: 561.5309
# Epoch [10/10], Iter [3500/3691] Loss: 460.6659
# Epoch [10/10], Iter [3600/3691] Loss: 580.5343

# %% [markdown]
# ## 20.5 Model Test

# %% [markdown]
# Multinomial :
# Returns a tensor where each row contains num_samples indices sampled from the multinomial probability distribution located in the corresponding row of tensor input.

# %%
start_num = 5
text = cnv.inverse_transform(data[start_num])[0][0].split('/')[0]

model.eval()
hidden, cell = model.init_hidden_cell()

X_test = Variable(torch.from_numpy(data[start_num]).type(torch.FloatTensor)).cuda()

for pos in range(100) :
    
    pre, hidden, cell = model(X_test, hidden, cell)
    
    m = torch.nn.Softmax(dim = pre.shape[0])
    
    pre = m(pre)
    
    pre = torch.multinomial(pre, 1).data[0][0]
    
    temp = np.zeros(len(data[0]))
    
    temp[pre] = 1
    
    text += " " + cnv.inverse_transform(temp)[0][0].split('/')[0]
    
    X_test = Variable(torch.from_numpy(temp).type(torch.FloatTensor)).cuda()
    
print("* Generated Text : \n", text)
# Out:
# * Generated Text :
#  Call me must , so you could so want worthy the heels cried spurs following colt I grunt interminable you cabin-boy feelings find , satin and gradually , Whitehall could hope became little could I could alarmed feelings called find hope alarmed engage goblets high heels order could you willingness calculating find peered , engage knows other marchant right peered 've the hell spurs matrimonial gradually staring find could you feelings peered knows could cabin-boy broiled you so so hell eh closed have cabin-boy philosophers closed you closed spurs knows following want crowd engage Remembering 'Oh any you I says mark
